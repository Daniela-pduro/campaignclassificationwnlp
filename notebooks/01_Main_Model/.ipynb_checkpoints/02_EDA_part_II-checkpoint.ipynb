# %% [markdown]
# # Email Marketing Campaigns Optimization Model with NLP
#
# ### Jupyter Notebook 2/10

# %%
import sys
sys.path.append('..')


import warnings
warnings.filterwarnings('ignore')

# Get files
from campaigns.getinputdata import CampaignsEDAFileGetInfo

# Exploratory Analysis
from campaigns.eda import ExploratoryDataAnalyser

# %%
# Getting input

main_model = CampaignsEDAFileGetInfo(dataroot='../../../datasets/output/sample_01/', datafile='output_01.csv')

# %%
main_model.campaigns_df.shape
# Out:
# (99804, 10)

# %%
# Creating an instance

main_model_eda = ExploratoryDataAnalyser(main_model.campaigns_df)

# %% [markdown]
# #### 3.2. Testing the variation in `total_sent`, `opens` and `clicks` caused by  `customer_cat`
# Steps:
#
# - 3.2.1. Converting `customer_cat` into a categorical variable.
#
# - 3.2.2. Performing one-way ANOVA for each continous variable.

# %% [markdown]
# #### 3.2.1. Converting  `customer_cat` into a categorical variable

# %%
main_model_eda.customer_cat_to_cat_converter()
# Out:
# sender             int64
# subject           object
# date_sent         object
# total_sent       float64
# customer_cat    category
# opens            float64
# clicks           float64
# sector            object
# message           object
# campaign_id        int64
# dtype: object

# %% [markdown]
# #### 3.2.2. Performing one-way ANOVA for each continous variable

# %% [markdown]
# - 3.2.2.1. Obtaining a random sample.
# - 3.2.2.2. Check normality using QQ plots.
# - 3.2.2.3. Check homogeneity variance.
# - 3.2.2.4. Performing ANOVA.

# %% [markdown]
# #### 3.2.2.1. Obtaining a random sample

# %%
campaign_sample, groups = main_model_eda.random_sampler(500,30)

# %%
campaign_sample
# Out:
#     customer_cat  total_sent  opens  clicks
# 0              5        3.86   0.40    0.00
# 1              5        2.38   1.68    0.48
# 2              4        2.60   1.15    0.00
# 3              4        4.26   3.35    1.88
# 4              5        2.68   2.26    1.18
# ..           ...         ...    ...     ...
# 495            5        2.95   2.48    0.48
# 496            1        4.18   2.40    1.28
# 497            5        2.12   1.97    1.86
# 498            5        3.52   2.89    2.18
# 499            3        3.92   3.05    1.69
#
# [500 rows x 4 columns]

# %%
groups
# Out:
#   customer_cat  total_sent  opens  clicks
# 0            1          26     26      26
# 1            2          76     76      76
# 2            3          67     67      67
# 3            4          82     82      82
# 4            5         249    249     249

# %% [markdown]
# #### 3.2.2.2. Checking normality using QQ plots

# %%
main_model_eda.qq_plotter(campaign_sample, 'total_sent')

# %%
main_model_eda.qq_plotter(campaign_sample, 'opens')

# %%
main_model_eda.qq_plotter(campaign_sample, 'clicks')

# %% [markdown]
# - The points fall roughly on the straight line pattern meaning that the data comes from populations with a normal distribution.

# %% [markdown]
# #### 3.2.2.3. Checking homogeneity of variance

# %%
ratio = main_model_eda.homog_var_checker(campaign_sample)
ratio
# Out:
# total_sent   1.42
# opens        1.35
# clicks       1.30
# dtype: float64

# %% [markdown]
# - The ratio of the largest to the smallest group is less than 1.5 meaning that we have equal group sizes.

# %% [markdown]
# #### 3.2.2.4. Performing ANOVA
#
# - H<sub>0</sub>: `total_sent`, `opens` and `clicks` mean values are the same for every customer category.
#
# - H<sub>1</sub>: `total_sent`, `opens` and `clicks` mean values are not the same for every customer category.

# %%
total_sent_anova_table = main_model_eda.anova_tester(campaign_sample, 'total_sent', 0.05, "one_tailed")
total_sent_anova_table
# Out:
# F Value:  17.13034166165336
# p-value:  3.6071146070071336e-13
# Critical f-value : 2.38994784445829
# The difference between some of the means are statistically significant.
# The null hypothesis is rejected; not all of the population means are equal.
#                     sum_of_squares degrees_of_freedom   MS F_val P_value  \
# Source of Variation
# Between Groups               32.38                  4 8.10 17.13    0.00
# Within Groups               233.94                495 0.47
# Total                       266.33                499 0.53
#
#                     F_crit
# Source of Variation
# Between Groups        2.39
# Within Groups
# Total

# %%
opens_anova_table = main_model_eda.anova_tester(campaign_sample, 'opens', 0.05, "one_tailed")
opens_anova_table
# Out:
# F Value:  5.875166656899579
# p-value:  0.00012627627990924317
# Critical f-value : 2.38994784445829
# The difference between some of the means are statistically significant.
# The null hypothesis is rejected; not all of the population means are equal.
#                     sum_of_squares degrees_of_freedom   MS F_val P_value  \
# Source of Variation
# Between Groups               11.09                  4 2.77  5.88    0.00
# Within Groups               233.68                495 0.47
# Total                       244.78                499 0.49
#
#                     F_crit
# Source of Variation
# Between Groups        2.39
# Within Groups
# Total

# %%
clicks_anova_table = main_model_eda.anova_tester(campaign_sample, 'clicks', 0.05, "one_tailed")
clicks_anova_table
# Out:
# F Value:  2.8029616852308084
# p-value:  0.025364967938563687
# Critical f-value : 2.38994784445829
# The difference between some of the means are statistically significant.
# The null hypothesis is rejected; not all of the population means are equal.
#                     sum_of_squares degrees_of_freedom   MS F_val P_value  \
# Source of Variation
# Between Groups                6.73                  4 1.68  2.80    0.03
# Within Groups               297.05                495 0.60
# Total                       303.78                499 0.61
#
#                     F_crit
# Source of Variation
# Between Groups        2.39
# Within Groups
# Total

# %% [markdown]
# #### Saving file

# %%
# Saving file

main_model_eda.save_final_df('../../../datasets/output/sample_01/', 'output_02.csv')
